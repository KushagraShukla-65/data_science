# %%
import pandas as pd
df=pd.read_csv("student_marks.csv")
df.head(5)
# Out:
#    Student_ID          Name  Maths  Physics  Chemistry  English  Computer  \
# 0         101   Aman Sharma     78       82         74       80        85
# 1         102    Riya Verma     92       88         91       90        94
# 2         103   Karan Singh     65       70         68       72        66
# 3         104    Neha Gupta     85       89         84       88        90
# 4         105  Rohit Mishra     55       60         58       62        57
#
#    Total  Percentage Grade
# 0    399        79.8     B
# 1    455        91.0     A
# 2    341        68.2     C
# 3    436        87.2     A
# 4    292        58.4     D

# %%
df.describe()
# Out:
#        Student_ID      Maths    Physics  Chemistry    English   Computer  \
# count    10.00000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    105.50000  77.900000  79.700000  79.400000  79.300000  80.400000
# std       3.02765  12.853447  11.096045  11.692353  10.133004  13.393199
# min     101.00000  55.000000  60.000000  58.000000  62.000000  57.000000
# 25%     103.25000  68.500000  71.250000  72.500000  72.500000  70.000000
# 50%     105.50000  79.500000  80.500000  80.500000  78.500000  82.500000
# 75%     107.75000  87.250000  88.750000  88.500000  87.500000  90.750000
# max     110.00000  95.000000  93.000000  96.000000  94.000000  97.000000
#
#             Total  Percentage
# count   10.000000   10.000000
# mean   396.700000   79.340000
# std     58.389592   11.677918
# min    292.000000   58.400000
# 25%    353.500000   70.700000
# 50%    399.500000   79.900000
# 75%    444.250000   88.850000
# max    475.000000   95.000000

# %%
df=pd.read_csv("pandas_groupby.csv")
g=df.groupby("City")
g

# %%
g["Revenue"].mean()
# Out:
# City
# Bangalore    19360.500000
# Bhopal       15401.478261
# Delhi        18297.312500
# Mumbai       17158.550000
# Varanasi     16044.956522
# Name: Revenue, dtype: float64

# %%
from matplotlib import pyplot as plt
df_sales=pd.read_excel("sales_data.xlsx")
plt.figure(figsize=(10,5))
plt.plot(df_sales["Month"],df_sales["Sales"],color="yellow",label="Sales")
plt.title("Monthly Sales Growth")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
import seaborn as sns
tips=pd.read_excel("tips_dataset.xlsx")
sns.boxplot(data=tips, x="day", y="tip")
plt.title("Tip Distribution by Day")

# %%
df=pd.read_csv("iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# checking null values
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
df.duplicated().sum()
# checking duplicated values
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
sns.histplot(data=df,x="SepalLengthCm",kde=True)
plt.xlabel("Sepal Length")
plt.ylabel("Count")
plt.title("Sepal Length Distribution")

# %%
sns.scatterplot(data=df,x="PetalLengthCm",y="PetalWidthCm",hue="Species")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("Petal Width Distribution")

# %%
sns.boxplot(data=df,x="Species",y="PetalLengthCm")
plt.xlabel("Species")
plt.ylabel("Petal Length")
plt.title("Petal Length Distribution")
